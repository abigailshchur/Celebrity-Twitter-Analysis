# %% [markdown]
# ## Importing Data:

# %%
from collections import defaultdict
from textblob import TextBlob
import numpy as np
import pickle
import pandas as pd
import csv
import io, json
import re

# %%
top_twitter_users = ["@KingJames", "@KDTrey5", "@StephenCurry30", "@Cristiano", "@JohnCena",
                    "@BarackObama", "@realDonaldTrump", "@HillaryClinton", "@BernieSanders", "@tedcruz",
                    "@Oprah", "@RyanSeacrest", "@TheEllenShow", "@jimmykimmel", "@jimmyfallon",
                    "@KimKardashian","@justinbieber", "@KevinHart4real", "@ArianaGrande", "@ddlovato"];
top_twitter_users_lowered = [x.lower() for x in top_twitter_users]
twitter_users_idx = defaultdict(int)
for i in range(len(top_twitter_users)):
    twitter_users_idx[top_twitter_users[i]]=i

# %%
all_tweets = pickle.load(open("all_tweets_half.p", "rb"))
all_tweets_old = pickle.load(open("all_tweets.p", "rb"))

# %%
for i in all_tweets_old:
    if i in top_twitter_users and i not in all_tweets:
        all_tweets[i] = all_tweets_old[i]

# %% [markdown]
# ## Getting Subset of Tweets

# %%
def get_recipient(tweet):
    return re.findall(r'\B\@\w+\b', tweet)

# %%
for user in top_twitter_users:
    for i in range(len(all_tweets[user])):
        all_tweets[user][i]['recipient'] = get_recipient(all_tweets[user][i]['text'])

# %%
good_tweets = defaultdict(list)
for user in top_twitter_users:
    for tweet in all_tweets[user]:
        for recipient in tweet['recipient']:
            tweet2=tweet.copy()
            if (recipient.lower() in top_twitter_users_lowered) and (not recipient.lower()==user.lower()):
                tweet2['recipient'] = [recipient]
                good_tweets[user].append(tweet2)
                break

# %% [markdown]
# ## Doing Some Sentiment Analysis

# %%
## REFERENCE : https://github.com/praritlamba/Mining-Twitter-Data-for-Sentiment-Analysis ##
def processTweet(tweet_text):
    tweet_text = tweet_text.lower()
    tweet_text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','URL',tweet_text)
    tweet_text = re.sub('@[^\s]+','AT_USER',tweet_text)
    tweet_text = re.sub('[\s]+', ' ', tweet_text)
    tweet_text = re.sub(r'#([^\s]+)', r'\1', tweet_text)
    tweet_text = tweet_text.strip('\'"')
    return tweet_text

def get_tweet_sentiment(tweet):
    analysis = TextBlob(processTweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 1 # positive
    elif analysis.sentiment.polarity == 0:
        return 0 # neutral
    else:
        return -1 # negative

# %%
for user in top_twitter_users:
    for i in range(len(good_tweets[user])):
        good_tweets[user][i]['sentiment'] = get_tweet_sentiment(good_tweets[user][i]['text'])

# %% [markdown]
# ## Creating table for tweets and sentiment for manual sentiment analysis

# %%
tweets = []
sentiment = []
for user in top_twitter_users:
    for tweet in good_tweets[user]:
        tweets.append(tweet["text"].encode('ascii',errors='ignore'))
        sentiment.append(tweet["sentiment"])

# %%
aggTable = pd.DataFrame({'text': tweets, 'sentiment': sentiment})
aggTable.to_csv('sentiment_table_old.csv')

# %%
aggTable = pd.read_csv('sentiment_table_new.csv')

# %%
aggTable
# Out:
#       Unnamed: 0  sentiment                                               text
# 0              0          1  RT @beatsbydre: Mind over matter--it's more th...
# 1              1          1  RT @LittleTikes: Excited to celebrate our @LJF...
# 2              2          1  RT @TheEllenShow: .@KingJames is on my show to...
# 3              3          1  @StephenCurry30 needs to stop it man!! He's ri...
# 4              4          1  Even in defeat and even playing horrible(perso...
# 5              5          1  RT @jimmyfallon: Ha!!!! It's all Bill. Go see ...
# 6              6          1  RT @JuddApatow: Trainwreck is in movie theater...
# 7              7          1  Thanks to #dubnation for making me a starter i...
# 8              8         -1  Won't be smiling after the game tonight @KDTre...
# 9              9          1  Talking golf and my @BritaUSA partnership with...
# 10            10          1  Congrats to the newest member of #DubNation @K...
# 11            11          1  RT @Money23Green: Man @BarackObama is the MAN!...
# 12            12          1  RT @BETSports: .@StephenCurry30 @CP3 @KingJame...
# 13            13          1  Man what?? Thanks 2 everyone who voted. Amazin...
# 14            14          1        @KevinHart4real thanks bro. Dream come true
# 15            15          1  RT @TheEllenShow: .@JohnCena, I love you! http...
# 16            16          0  Tonight! Watch me on @JimmyKimmel on ABC! #KIM...
# 17            17          1  Given to me by @TheEllenShow for #CenaReturns ...
# 18            18          1  Still reeling off of #WHCD . @BarackObama unre...
# 19            19          1  Thank you @TheEllenShow for the @tictacglobal ...
# 20            20          1  What can I say? @jimmyfallon @FallonTonight yo...
# 21            21          1  RT @jimmyfallon: Fun show tonight: @SusanSaran...
# 22            22          0  RT @jimmyfallon: Tonight: Presidential candida...
# 23            23          1  Oh yeah, and go see #Trainwreck @amyschumer @J...
# 24            24          1  RT @JuddApatow: Trainwreck is in movie theater...
# 25            25          0  .@NBA Finals shows us one thing. #NeverGiveUp....
# 26            26          1  RT @adambvary: Two stealth MVPs of TRAINWRECK:...
# 27            27          0  RT @FallonTonight: .@POTUS and @jimmyfallon Sl...
# 28            28          0  Watch President Obama thank @TheEllenShow for ...
# 29            29          0  RT @TheEllenShow: .@BarackObama was here in 20...
# ...          ...        ...                                                ...
# 1123        1123          0  RT @glaad: .@KimKardashian, @LionelRichie, @Ke...
# 1124        1124          0  Congrats @RyanSeacrest and @RyanFoundation on ...
# 1125        1125          1  @ArianaGrande YEESSS YESSS YESSSS!!!!!! So pro...
# 1126        1126          0  RT @AmericanIdol: West Coast, it's time for #D...
# 1127        1127          0  RT @HillaryClinton: #GOPdebate https://t.co/SG...
# 1128        1128          0  RT @HillaryClinton: We did it, South Carolina....
# 1129        1129          0  RT @HillaryClinton: RT if you're standing with...
# 1130        1130          0  RT @JussieSmollett: With @leonbridges &amp; @d...
# 1131        1131          1  @ArianaGrande and by shat ourselves we mean we...
# 1132        1132          0                      YO.. SO LIT!!!  @ArianaGrande
# 1133        1133          1  RT @ArianaGrande: Friday night was lit and by ...
# 1134        1134          1  RT @HillaryClinton: We feel very blessed with ...
# 1135        1135          1  RT @HillaryClinton: Its not whether you get kn...
# 1136        1136          0  RT @TheEllenShow: This performance by @ddlovat...
# 1137        1137          1  RT @HillaryClinton: Text CONGRATS to 47246 to ...
# 1138        1138          0  RT @ChloeGMoretz: My girl won Iowa !!!!!! @Hil...
# 1139        1139          1  RT @HillaryClinton: Today is the #IAcaucus! RT...
# 1140        1140          1  Love you tons Iowa... Will post pics ASAP!! #I...
# 1141        1141          1  Congrats @TheEllenShow on your @PeoplesChoice ...
# 1142        1142          1                     You're the best @TheEllenShow
# 1143        1143          1  RT @TheEllenShow: .@ddlovato, you just tore it...
# 1144        1144          1  Ummm... @ArianaGrande - you look GORGEOUS and ...
# 1145        1145          0  RT @InStyle: .@JohnLegend and @ddlovato to per...
# 1146        1146          0  It always means a lot coming from you girly!!!...
# 1147        1147          1  RT @ArianaGrande: had to hit up @ddlovato last...
# 1148        1148          0                  RT @KimKardashian: 13. Mr. Hughes
# 1149        1149          1                RT @RyanSeacrest: 7. Waitin For You
# 1150        1150          1  I'm hosting @AmericanTop40 this weekend!!! Tun...
# 1151        1151          1  RT @dilmerarmy:  I love you guys @ddlovato @Ta...
# 1152        1152          1  RT @RyanSeacrest: if ur in NYC area and a fan ...
#
# [1153 rows x 3 columns]

# %%
tweet_to_sentiment = {}
for i in range(len(aggTable)):
    tweet_to_sentiment[aggTable["text"][i]] = aggTable["sentiment"][i]

# %%
data_combined = {}
for user in top_twitter_users:
    for tweet in good_tweets[user]:
        for recipient in tweet["recipient"]:
            data_combined[user.lower()+" "+recipient.lower()] = {"pos":0, "neg":0, "neutral":0}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8107a7faafad> in <module>()
#       1 data_combined = {}
#       2 for user in top_twitter_users:
# ----> 3     for tweet in good_tweets[user]:
#       4         for recipient in tweet["recipient"]:
#       5             data_combined[user.lower()+" "+recipient.lower()] = {"pos":0, "neg":0, "neutral":0}
#
# NameError: name 'good_tweets' is not defined

# %%
for user in top_twitter_users:
    for tweet in good_tweets[user]:
        if tweet["text"] in tweet_to_sentiment:
            s = tweet_to_sentiment[tweet["text"]]
        else:
            s = 0
        for recipient in tweet["recipient"]:
            if s==-1:
                data_combined[user.lower()+" "+recipient.lower()]["neg"]+=1
            elif s==1:
                data_combined[user.lower()+" "+recipient.lower()]["pos"]+=1
            else:
                data_combined[user.lower()+" "+recipient.lower()]["neutral"]+=1

# %%
data_combined2 = {}
for user1 in top_twitter_users:
    for user2 in top_twitter_users:
        if user1.lower()+" "+user2.lower() in data_combined:
            data_combined2[user1+" "+user2] = data_combined[user1.lower()+" "+user2.lower()]

# %%
with io.open('reply_sentiment_counts.json', 'w', encoding='utf-8') as f:
  f.write(unicode(json.dumps(data_combined2, ensure_ascii=False)))
